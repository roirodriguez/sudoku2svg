# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sudoku2svg import SudokuBuilder, sudoku2svg
from IPython.display import display, HTML

def display_svg(svgdata):
    display(HTML('<div style="width: 400px;">' + svgdata.decode('utf-8') + '</div>'))
    

SUDOKU_STR = "000007800080050090100600000500108600030000040009206003000002007040010020007300000"
sudoku = SudokuBuilder.fromString(SUDOKU_STR)
svgdata = sudoku2svg(sudoku)
display_svg(svgdata)
# Out:
# <div style="width: 400px;"><?xml version='1.0' encoding='ASCII'?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" viewBox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg">
#     <defs>
#         <style type="text/css"><![CDATA[
#             .sudoku-grid {
#     text-align: center;
# }
#
# .sudoku-grid .line {
#     stroke: #7b7878;
#     stroke-width: 2;
# }
#
# .sudoku-grid .line-bold {
#     stroke: #333333;
#     stroke-width: 5;
#     stroke-linejoin: round;
# }
#
# .grid-bg { fill: white; }
#
# .cell-bg .color-code-1 { fill: transparent; }
# .cell-bg .color-code-2 { fill: #ffb8bc; }
# .cell-bg .color-code-3 { fill: #ffd085; }
# .cell-bg .color-code-4 { fill: #ffffb6; }
# .cell-bg .color-code-5 { fill: #caf9ca; }
# .cell-bg .color-code-6 { fill: #f1dbff; }
# .cell-bg .color-code-7 { fill: #c8f7ff; }
# .cell-bg .color-code-8 { fill: #ffa8d8; }
# .cell-bg .color-code-9 { fill: #d7d7d7; }
#
# text.digit {
# ...

# %%
sudoku.cells[0].value = 4
sudoku.cells[3].value = 9
sudoku.cells[4].value = 2
sudoku.cells[7].corner_marks = [1,3]
sudoku.cells[8].corner_marks = [1]
sudoku.cells[12].value = 4
sudoku.cells[14].value = 1
sudoku.cells[15].corner_marks = [3,7]
sudoku.cells[19].value = 9
sudoku.cells[22].value = 8
sudoku.cells[23].value = 3
sudoku.cells[24].corner_marks = [4,7]
sudoku.cells[25].value = 5
sudoku.cells[26].corner_marks = [4]
sudoku.cells[28].value = 2
sudoku.cells[29].value = 4
sudoku.cells[31].value = 3
sudoku.cells[34].value = 7
sudoku.cells[35].value = 9
sudoku.cells[36].value = 8
sudoku.cells[38].value = 1
sudoku.cells[39].center_marks = [5,7]
sudoku.cells[39].bgcolor = 3
sudoku.cells[40].center_marks = [9,7]
sudoku.cells[40].bgcolor = 4
sudoku.cells[41].center_marks = [5,9]
sudoku.cells[41].bgcolor = 5
sudoku.cells[45].center_marks = [6,7]
sudoku.cells[46].center_marks = [6,7]
sudoku.cells[49].value = 4
sudoku.cells[52].value = 8
sudoku.cells[58].center_marks = [6,7,9]
sudoku.cells[58].corner_marks = [6]
sudoku.cells[72].corner_marks = [2]
sudoku.cells[73].corner_marks = [2]
sudoku.cells[76].center_marks = [6,7,9]
sudoku.cells[76].corner_marks = [6]

svgdata = sudoku2svg(sudoku)
display_svg(svgdata)
# Out:
# <div style="width: 400px;"><?xml version='1.0' encoding='ASCII'?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" viewBox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg">
#     <defs>
#         <style type="text/css"><![CDATA[
#             .sudoku-grid {
#     text-align: center;
# }
#
# .sudoku-grid .line {
#     stroke: #7b7878;
#     stroke-width: 2;
# }
#
# .sudoku-grid .line-bold {
#     stroke: #333333;
#     stroke-width: 5;
#     stroke-linejoin: round;
# }
#
# .grid-bg { fill: white; }
#
# .cell-bg .color-code-1 { fill: transparent; }
# .cell-bg .color-code-2 { fill: #ffb8bc; }
# .cell-bg .color-code-3 { fill: #ffd085; }
# .cell-bg .color-code-4 { fill: #ffffb6; }
# .cell-bg .color-code-5 { fill: #caf9ca; }
# .cell-bg .color-code-6 { fill: #f1dbff; }
# .cell-bg .color-code-7 { fill: #c8f7ff; }
# .cell-bg .color-code-8 { fill: #ffa8d8; }
# .cell-bg .color-code-9 { fill: #d7d7d7; }
#
# text.digit {
# ...

# %%
SUDOKU_STR = "1002000002100000"
sudoku = SudokuBuilder.fromString(SUDOKU_STR)

sudoku.cells[4].value = 2
sudoku.cells[7].value = 1
sudoku.cells[13].value = 1
sudoku.cells[14].value = 2

for cell in sudoku.cells:
    if not cell.value:
        cell.center_marks = [3, 4]
        
sudoku.cells[1].bgcolor = 4
sudoku.cells[2].bgcolor = 5
sudoku.cells[5].bgcolor = 5
sudoku.cells[6].bgcolor = 4

sudoku.cells[8].bgcolor = 6
sudoku.cells[11].bgcolor = 7
sudoku.cells[12].bgcolor = 7
sudoku.cells[15].bgcolor = 6

svgdata = sudoku2svg(sudoku)
display_svg(svgdata)
# Out:
# <div style="width: 400px;"><?xml version='1.0' encoding='ASCII'?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg version="1.1" viewBox="0 0 500 500" xmlns="http://www.w3.org/2000/svg">
#     <defs>
#         <style type="text/css"><![CDATA[
#             .sudoku-grid {
#     text-align: center;
# }
#
# .sudoku-grid .line {
#     stroke: #7b7878;
#     stroke-width: 2;
# }
#
# .sudoku-grid .line-bold {
#     stroke: #333333;
#     stroke-width: 5;
#     stroke-linejoin: round;
# }
#
# .grid-bg { fill: white; }
#
# .cell-bg .color-code-1 { fill: transparent; }
# .cell-bg .color-code-2 { fill: #ffb8bc; }
# .cell-bg .color-code-3 { fill: #ffd085; }
# .cell-bg .color-code-4 { fill: #ffffb6; }
# .cell-bg .color-code-5 { fill: #caf9ca; }
# .cell-bg .color-code-6 { fill: #f1dbff; }
# .cell-bg .color-code-7 { fill: #c8f7ff; }
# .cell-bg .color-code-8 { fill: #ffa8d8; }
# .cell-bg .color-code-9 { fill: #d7d7d7; }
#
# text.digit {
# ...
